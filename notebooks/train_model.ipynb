# %%
from predictive_maintenance.models import IMSAnomalyDetector

if __name__ == "__main__":
    detector = IMSAnomalyDetector()
    detector.run()
# Out:
# 2025-12-11 20:12:54,289 - INFO - >>> Pipeline started: Generating Dataset...
# 2025-12-11 20:12:54,290 - INFO - >>> Scanning for healthy bearings...
# 2025-12-11 20:12:54,316 - INFO - ✔ Healthy bearings list: [(1, 1), (1, 2), (2, 2), (2, 3), (2, 4), (3, 1), (3, 2), (3, 4)]
# 2025-12-11 20:13:27,650 - INFO - Fitting Scaler...
# 2025-12-11 20:13:27.662606: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-12-11 20:13:28,437 - INFO - Total Available: 161 | Using Subset: 32 (Ratio: 0.2)
# 2025-12-11 20:13:28,439 - INFO - Splitting Subset -> Train: 25 | Val: 7
# 2025-12-11 20:13:28,456 - INFO - >>> Building Model...
# 2025-12-11 20:13:28,567 - INFO - >>> Training Started...
# Epoch 1/40
# 2025-12-11 20:13:36.258871: E tensorflow/core/util/util.cc:131] oneDNN supports DT_INT32 only on platforms with AVX-512. Falling back to the default Eigen-based implementation if present.
# ...
