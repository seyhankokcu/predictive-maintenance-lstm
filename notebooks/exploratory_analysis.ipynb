# %%
from predictive_maintenance.visualization import (
    plot_discriminator_analysis,
    plot_experiment_eda_with_fixed_scales,
    plot_frequency_features_comparison,
    plot_pca_vs_raw_comparison,
    plot_wavelet_features_comparison,
    visualize_timestamp_continuity,
)

# %%
PARQUET_PATH = "../data/processed/IMS_Parquet_Data"

# %%
visualize_timestamp_continuity(dataset_path=PARQUET_PATH)
# Out:
# Starting Timestamp Continuity Analysis...

# %%
plot_pca_vs_raw_comparison(
    base_dir="../data/raw/IMS",
    pca_dir="../data/interim/1st_test_pca_applied",
    bearing_id=1,
)
# Out:
# --- PCA vs Raw Comparison (Bearing 1) ---

# %%
plot_experiment_eda_with_fixed_scales(test_id=1, dataset_path=PARQUET_PATH)
# Out:
# ===== Time-Domain Analysis: Test 1 =====
# Saved figure: experiment_1_time_features.png

# %%
plot_experiment_eda_with_fixed_scales(test_id=2, dataset_path=PARQUET_PATH)
# Out:
# ===== Time-Domain Analysis: Test 2 =====
# Saved figure: experiment_2_time_features.png

# %%
plot_experiment_eda_with_fixed_scales(test_id=3, dataset_path=PARQUET_PATH)
# Out:
# ===== Time-Domain Analysis: Test 3 =====
# Saved figure: experiment_3_time_features.png

# %%
plot_frequency_features_comparison(test_id=1, dataset_path=PARQUET_PATH)
# Out:
# ===== Frequency Analysis: Test 1 =====
# Saved figure: experiment_1_freq_features.png

# %%
plot_frequency_features_comparison(test_id=2, dataset_path=PARQUET_PATH)
# Out:
# ===== Frequency Analysis: Test 2 =====
# Saved figure: experiment_2_freq_features.png

# %%
plot_frequency_features_comparison(test_id=3, dataset_path=PARQUET_PATH)
# Out:
# ===== Frequency Analysis: Test 3 =====
# Saved figure: experiment_3_freq_features.png
